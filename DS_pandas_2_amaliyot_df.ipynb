# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjar-prog/Telegram-JavaScript-Bot/blob/main/DS_pandas_2_amaliyot_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # **DATA SCIENCE VA SUN'IY INTELLEKT PRAKTIKUM**
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# # **AMALIYOT**
# ## DataFrame

# %% [markdown]
# ### **1-mashq**. `Pandas` kutubxonasini `pd`, `numpy` kutubxonasini `np` deb chaqirib oling

# %%
# Javobni shuyerga yozing
import pandas as pd
import numpy as np

# %%
#@title **To'g'ri javob**
import pandas as pd
import numpy as np

# %% [markdown]
# ### **2-mashq.** Quyida ko'rsatilgan dataframeni yarating va `df` deb nomlang

# %%
# Javobni shuyerga yozing
import pandas as pd

# DataFrame yaratish
data = {
    "Ism": ["Ali", "Vali", "Hasan", "Husan", "Olim"],
    "Yosh": [25, 30, 22, 29, 24],
    "Kasb": ["Dasturchi", "Muhandis", "O'qituvchi", "Shifokor", "Talaba"]
}

df = pd.DataFrame(data)

# Natijani chiqarish
print(df)
# Out:
#      Ism  Yosh        Kasb
# 0    Ali    25   Dasturchi
# 1   Vali    30    Muhandis
# 2  Hasan    22  O'qituvchi
# 3  Husan    29    Shifokor
# 4   Olim    24      Talaba

# %%
# @title **To'g'ri javob**
viloyatlar = [
    "Andijon viloyati",
    "Buxoro viloyati",
    "Fargona viloyati",
    "Jizzax viloyati",
    "Xorazm viloyati",
    "Namangan viloyati",
    "Navoiy viloyati",
    "Qashqadaryo viloyati",
    "Qoraqalpogʻiston Respublikasi",
    "Samarqand viloyati",
    "Sirdaryo viloyati",
    "Surxondaryo viloyati",
    "Toshkent viloyati",
]
markazlar = [
    "Andijon shahri",
    "Buxoro shahri",
    "Fargona shahri",
    "Jizzax shahri",
    "Urganch shahri",
    "Namangan shahri",
    "Navoiy shahri",
    "Qarshi shahri",
    "Nukus shahri",
    "Samarqand shahri",
    "Guliston shahri",
    "Termiz shahri",
    "Nurafshon shahri",
]
maydonlar = [
    4200,
    39400,
    6800,
    20500,
    6300,
    7900,
    110800,
    28400,
    160000,
    16400,
    5100,
    20800,
    15300,
]
aholi = [
    1899000,
    1384700,
    2597000,
    910500,
    1200000,
    1862000,
    767500,
    2029000,
    1200000,
    2322000,
    648100,
    1676000,
    4450000,
]
data = {
    "Hudud":viloyatlar,
    "Markaz":markazlar,
    "Maydoni":maydonlar,
    "Aholisi":aholi
}
df = pd.DataFrame(data)
df
# Out:
#                             Hudud            Markaz  Maydoni  Aholisi
# 0                Andijon viloyati    Andijon shahri     4200  1899000
# 1                 Buxoro viloyati     Buxoro shahri    39400  1384700
# 2                Fargona viloyati    Fargona shahri     6800  2597000
# 3                 Jizzax viloyati     Jizzax shahri    20500   910500
# 4                 Xorazm viloyati    Urganch shahri     6300  1200000
# 5               Namangan viloyati   Namangan shahri     7900  1862000
# 6                 Navoiy viloyati     Navoiy shahri   110800   767500
# 7            Qashqadaryo viloyati     Qarshi shahri    28400  2029000
# 8   Qoraqalpogʻiston Respublikasi      Nukus shahri   160000  1200000
# 9              Samarqand viloyati  Samarqand shahri    16400  2322000
# 10              Sirdaryo viloyati   Guliston shahri     5100   648100
# 11           Surxondaryo viloyati     Termiz shahri    20800  1676000
# ...

# %% [markdown]
# ### **2-mashq.** Yuqoridagi df ning yuqorisidan 5 ta qator chiqaring

# %%
# Javobni shuyerga yozing
print(df.head(5))
# Out:
#               Hudud          Markaz  Maydoni  Aholisi
# 0  Andijon viloyati  Andijon shahri     4200  1899000
# 1   Buxoro viloyati   Buxoro shahri    39400  1384700
# 2  Fargona viloyati  Fargona shahri     6800  2597000
# 3   Jizzax viloyati   Jizzax shahri    20500   910500
# 4   Xorazm viloyati  Urganch shahri     6300  1200000

# %%
#@title **To'g'ri javob**
df.head()
# Out:
#               Hudud          Markaz  Maydoni  Aholisi
# 0  Andijon viloyati  Andijon shahri     4200  1899000
# 1   Buxoro viloyati   Buxoro shahri    39400  1384700
# 2  Fargona viloyati  Fargona shahri     6800  2597000
# 3   Jizzax viloyati   Jizzax shahri    20500   910500
# 4   Xorazm viloyati  Urganch shahri     6300  1200000

# %% [markdown]
# ### **3-mashq.** Yuqoridagi df dan tasodifiy 3 ta qator chiqaring

# %%
# Javobni shuyerga yozing
print(df.sample(3))
# Out:
#               Hudud          Markaz  Maydoni  Aholisi
# 2  Fargona viloyati  Fargona shahri     6800  2597000
# 3   Jizzax viloyati   Jizzax shahri    20500   910500
# 4   Xorazm viloyati  Urganch shahri     6300  1200000

# %%
#@title **To'g'ri javob**
df.sample(3)
# Out:
#              Hudud          Markaz  Maydoni  Aholisi
# 4  Xorazm viloyati  Urganch shahri     6300  1200000
# 3  Jizzax viloyati   Jizzax shahri    20500   910500
# 1  Buxoro viloyati   Buxoro shahri    39400  1384700

# %% [markdown]
# ### **4-mashq.** Yuqoridagi df ning 'Hudud' va 'Aholisi' ustinlarini alohida df ko'rinishida chiqaring

# %%
# Javobni shuyerga yozing
df_yangi = df[['Hudud', 'Aholisi']]

# Natijani chiqarish
print(df_yangi)
# Out:
#                             Hudud  Aholisi
# 0                Andijon viloyati  1899000
# 1                 Buxoro viloyati  1384700
# 2                Fargona viloyati  2597000
# 3                 Jizzax viloyati   910500
# 4                 Xorazm viloyati  1200000
# 5               Namangan viloyati  1862000
# 6                 Navoiy viloyati   767500
# 7            Qashqadaryo viloyati  2029000
# 8   Qoraqalpogʻiston Respublikasi  1200000
# 9              Samarqand viloyati  2322000
# 10              Sirdaryo viloyati   648100
# 11           Surxondaryo viloyati  1676000
# 12              Toshkent viloyati  4450000

# %%
#@title **To'g'ri javob**
df[['Hudud','Aholisi']]
# Out:
#                             Hudud  Aholisi
# 0                Andijon viloyati  1899000
# 1                 Buxoro viloyati  1384700
# 2                Fargona viloyati  2597000
# 3                 Jizzax viloyati   910500
# 4                 Xorazm viloyati  1200000
# 5               Namangan viloyati  1862000
# 6                 Navoiy viloyati   767500
# 7            Qashqadaryo viloyati  2029000
# 8   Qoraqalpogʻiston Respublikasi  1200000
# 9              Samarqand viloyati  2322000
# 10              Sirdaryo viloyati   648100
# 11           Surxondaryo viloyati  1676000
# 12              Toshkent viloyati  4450000

# %% [markdown]
# ### **5-mashq.** Yuqoridagi df ning `Markaz` ustunini Series obyekti ko'rinishida chiqaring

# %%
# Javobni shuyerga yozing
markaz_series = df['Markaz']

# Natijani chiqarish
print(markaz_series)
# Out:
# 0       Andijon shahri
# 1        Buxoro shahri
# 2       Fargona shahri
# 3        Jizzax shahri
# 4       Urganch shahri
# 5      Namangan shahri
# 6        Navoiy shahri
# 7        Qarshi shahri
# 8         Nukus shahri
# 9     Samarqand shahri
# 10     Guliston shahri
# 11       Termiz shahri
# 12    Nurafshon shahri
# Name: Markaz, dtype: object

# %%
#@title **To'g'ri javob**
df.Markaz
# Out:
# 0       Andijon shahri
# 1        Buxoro shahri
# 2       Fargona shahri
# 3        Jizzax shahri
# 4       Urganch shahri
# 5      Namangan shahri
# 6        Navoiy shahri
# 7        Qarshi shahri
# 8         Nukus shahri
# 9     Samarqand shahri
# 10     Guliston shahri
# 11       Termiz shahri
# 12    Nurafshon shahri
# Name: Markaz, dtype: object

# %% [markdown]
# ### **6-mashq.** Yuqoridagi df dan aholi soni 2 milliondan oshiq bo'lgan hududlarni chiqaring

# %%
# Javobni shuyerga yozing
df_filtrlangan = df[df['Aholisi'] > 2000000]

# Natijani chiqarish
print(df_filtrlangan)
# Out:
#                    Hudud            Markaz  Maydoni  Aholisi
# 2       Fargona viloyati    Fargona shahri     6800  2597000
# 7   Qashqadaryo viloyati     Qarshi shahri    28400  2029000
# 9     Samarqand viloyati  Samarqand shahri    16400  2322000
# 12     Toshkent viloyati  Nurafshon shahri    15300  4450000

# %%
#@title **To'g'ri javob**
df[df.Aholisi>2_000_000]
# Out:
#                    Hudud            Markaz  Maydoni  Aholisi
# 2       Fargona viloyati    Fargona shahri     6800  2597000
# 7   Qashqadaryo viloyati     Qarshi shahri    28400  2029000
# 9     Samarqand viloyati  Samarqand shahri    16400  2322000
# 12     Toshkent viloyati  Nurafshon shahri    15300  4450000

# %% [markdown]
# ### **7-mashq.** Yuqoridagi df dan maydoni 10000kv.km dan kichik bo'lgan hududlarni chiqaring

# %%
# Javobni shuyerga yozing
df_filtrlangan = df[df['Maydoni'] < 10000]

# Natijani chiqarish
print(df_filtrlangan)
# Out:
#                 Hudud           Markaz  Maydoni  Aholisi
# 0    Andijon viloyati   Andijon shahri     4200  1899000
# 2    Fargona viloyati   Fargona shahri     6800  2597000
# 4     Xorazm viloyati   Urganch shahri     6300  1200000
# 5   Namangan viloyati  Namangan shahri     7900  1862000
# 10  Sirdaryo viloyati  Guliston shahri     5100   648100

# %%
#@title **To'g'ri javob**
df[df.Maydoni<10000]
# Out:
#                 Hudud           Markaz  Maydoni  Aholisi
# 0    Andijon viloyati   Andijon shahri     4200  1899000
# 2    Fargona viloyati   Fargona shahri     6800  2597000
# 4     Xorazm viloyati   Urganch shahri     6300  1200000
# 5   Namangan viloyati  Namangan shahri     7900  1862000
# 10  Sirdaryo viloyati  Guliston shahri     5100   648100

# %% [markdown]
# ### **8-mashq.** Yuqoridagi df ning birinchi ustunini df ning indeksi sifatida ishlating
# Ishora:
# 1. Yoki df ni qayta yarating
# 2. Yoki `set_index()` metodidan foydalaning

# %%
# Javobni shuyerga yozing
df = df.set_index(df.columns[0])  # Birinchi ustunni indeks qilish

# Natijani chiqarish
print(df)
# Out:
#                   Maydoni  Aholisi
# Markaz
# Andijon shahri       4200  1899000
# Buxoro shahri       39400  1384700
# Fargona shahri       6800  2597000
# Jizzax shahri       20500   910500
# Urganch shahri       6300  1200000
# Namangan shahri      7900  1862000
# Navoiy shahri      110800   767500
# Qarshi shahri       28400  2029000
# Nukus shahri       160000  1200000
# Samarqand shahri    16400  2322000
# Guliston shahri      5100   648100
# Termiz shahri       20800  1676000
# Nurafshon shahri    15300  4450000

# %%
#@title **To'g'ri javob**
df.set_index(df.columns[0], inplace=True)
df.head()
# Out:
#                           Markaz  Maydoni  Aholisi
# Hudud
# Andijon viloyati  Andijon shahri     4200  1899000
# Buxoro viloyati    Buxoro shahri    39400  1384700
# Fargona viloyati  Fargona shahri     6800  2597000
# Jizzax viloyati    Jizzax shahri    20500   910500
# Xorazm viloyati   Urganch shahri     6300  1200000

# %% [markdown]
# ### **9-mashq.** Yuqoridagi df dan, Aholisi 2 milliondan oshiq hududlar orasida Samarqand viloyati bor yoki yo'qligini tekshiring

# %%
# Javobni shuyerga yozing
# Aholisi 2 milliondan oshiq bo'lgan hududlar
katta_hududlar = df[df['Aholisi'] > 2000000]

# Samarqand viloyati shu ro'yxatda borligini tekshirish
samarqand_bormi = 'Samarqand' in katta_hududlar.index

# Natijani chiqarish
print(f"Samarqand viloyati 2 milliondan oshiq aholili hududlar orasida bormi? {samarqand_bormi}")
# Out:
# Samarqand viloyati 2 milliondan oshiq aholili hududlar orasida bormi? False

# %%
#@title **To'g'ri javob**
"Samarqand viloyati" in df[df.Aholisi>2_000_000].index
# Out:
# False

# %% [markdown]
# ### **10-mashq.**  Yuqoridagi df dan faqatgina Andijon, Farg'ona va Namangan viloyatlarini ajratib ko'rsating

# %%
# Javobni shuyerga yozing
import pandas as pd

# DataFrame misoli
data = {
    "Hudud": ["Andijon", "Buxoro", "Farg'ona", "Jizzax", "Namangan"],
    "Aholisi": [1899000, 1384700, 2597000, 910500, 1862000],
    "Maydon": [4200, 39400, 6800, 20500, 7900]
}

# DataFrame yaratish
df = pd.DataFrame(data)

# Indeksni "Hudud" ustuniga o'zgartirish
df = df.set_index("Hudud")

# Andijon, Farg'ona va Namangan viloyatlarini ajratish
tanlangan_viloyatlar = df.loc[["Andijon", "Farg'ona", "Namangan"]]

# Natijani chiqarish
print(tanlangan_viloyatlar)
# Out:
#           Aholisi  Maydon
# Hudud
# Andijon   1899000    4200
# Farg'ona  2597000    6800
# Namangan  1862000    7900

# %%
#@title **To'g'ri javob**
import pandas as pd

# DataFrame misoli
data = {
    "Hudud": ["Andijon", "Buxoro", "Farg'ona", "Jizzax", "Namangan"],
    "Aholisi": [1899000, 1384700, 2597000, 910500, 1862000],
    "Maydon": [4200, 39400, 6800, 20500, 7900]
}

# DataFrame yaratish
df = pd.DataFrame(data)

# Indeksni "Hudud" ustuniga o'zgartirish
df = df.set_index("Hudud")

# Andijon, Farg'ona va Namangan viloyatlarini ajratish
tanlangan_viloyatlar = df.loc[["Andijon", "Farg'ona", "Namangan"]]

# Natijani chiqarish
print(tanlangan_viloyatlar)
# Out:
#           Aholisi  Maydon
# Hudud
# Andijon   1899000    4200
# Farg'ona  2597000    6800
# Namangan  1862000    7900

# %% [markdown]
# ### **11-mashq.**  Yuqoridagi df dan Samarqanda va Toshkent viloyatlarining aholisi va maydonini alohida df ko'rinishida chiqaring

# %%
# Javobni shuyerga yozing
import pandas as pd

# DataFrame misoli
data = {
    "Hudud": ["Andijon", "Buxoro", "Farg'ona", "Jizzax", "Namangan",
              "Navoiy", "Qashqadaryo", "Qoraqalpog'iston Respublikasi",
              "Samarqand", "Sirdaryo", "Surxondaryo", "Toshkent"],
    "Aholisi": [1899000, 1384700, 2597000, 910500, 1862000,
                767500, 2029000, 1200000, 2322000, 648100,
                1676000, 4450000],
    "Maydon": [4200, 39400, 6800, 20500, 7900,
               110800, 28400, 160000, 16400, 5100,
               20800, 15300]
}

# DataFrame yaratish
df = pd.DataFrame(data)

# Indeksni "Hudud" ustuniga o'zgartirish
df = df.set_index("Hudud")

# Samarqand va Toshkent viloyatlarini ajratib olish
tanlangan_viloyatlar = df.loc[["Samarqand", "Toshkent"], ["Aholisi", "Maydon"]]

# Natijani chiqarish
print(tanlangan_viloyatlar)
# Out:
#            Aholisi  Maydon
# Hudud
# Samarqand  2322000   16400
# Toshkent   4450000   15300

# %%
#@title **To'g'ri javob**
import pandas as pd

# DataFrame misoli
data = {
    "Hudud": ["Andijon", "Buxoro", "Farg'ona", "Jizzax", "Namangan",
              "Navoiy", "Qashqadaryo", "Qoraqalpog'iston Respublikasi",
              "Samarqand", "Sirdaryo", "Surxondaryo", "Toshkent"],
    "Aholisi": [1899000, 1384700, 2597000, 910500, 1862000,
                767500, 2029000, 1200000, 2322000, 648100,
                1676000, 4450000],
    "Maydon": [4200, 39400, 6800, 20500, 7900,
               110800, 28400, 160000, 16400, 5100,
               20800, 15300]
}

# DataFrame yaratish
df = pd.DataFrame(data)

# Indeksni "Hudud" ustuniga o'zgartirish
df = df.set_index("Hudud")

# Samarqand va Toshkent viloyatlarini ajratib olish
tanlangan_viloyatlar = df.loc[["Samarqand", "Toshkent"], ["Aholisi", "Maydon"]]

# Natijani chiqarish
print(tanlangan_viloyatlar)
# Out:
#            Aholisi  Maydon
# Hudud
# Samarqand  2322000   16400
# Toshkent   4450000   15300

# %% [markdown]
# ### **12-mashq.**  Yuqoridagi df dan yangi df_new DataFrame yarating. Yangi dataframega faqatgina aholisi 1.5mln dan kam bo'lgan hududlarni ko'chiring.

# %%
# Javobni shuyerga yozing
# Aholisi 1.5 milliondan kam bo'lgan hududlarni ajratib olish
df_new = df[df["Aholisi"] < 1500000]

# Natijani chiqarish
print(df_new)
# Out:
#                                Aholisi  Maydon
# Hudud
# Buxoro                         1384700   39400
# Jizzax                          910500   20500
# Navoiy                          767500  110800
# Qoraqalpog'iston Respublikasi  1200000  160000
# Sirdaryo                        648100    5100

# %%
#@title **To'g'ri javob**
df_new = df[df.Aholisi<1_500_000]
df_new
# Out:
#                                Aholisi  Maydon
# Hudud
# Buxoro                         1384700   39400
# Jizzax                          910500   20500
# Navoiy                          767500  110800
# Qoraqalpog'iston Respublikasi  1200000  160000
# Sirdaryo                        648100    5100

# %% [markdown]
# ### **13-mashq.**  Yangi df qatorlari orasida Navoiy, Namangan va Xorazm viloyatlari borligini tekshiring

# %%
# Javobni shuyerga yozing
# Tekshiriladigan viloyatlar ro'yxati
tekshiruv = ["Navoiy", "Namangan", "Xorazm"]

# df_new dagi indekslarni tekshirish
for viloyat in tekshiruv:
    if viloyat in df_new.index:
        print(f"{viloyat} df_new da mavjud ✅")
    else:
        print(f"{viloyat} df_new da yo‘q ❌")
# Out:
# Navoiy df_new da mavjud ✅
# Namangan df_new da yo‘q ❌
# Xorazm df_new da yo‘q ❌

# %%
#@title **To'g'ri javob**
pd.Index(['Navoiy viloyati','Namangan viloyati','Xorazm viloyati']).isin(df_new.index)
# Out:
# array([False, False, False])

# %% [markdown]
# ### **14-mashq.**  Aholisi 1milliondan ko'p, lekin maydoni 10000kv.km dan kam hududlarni chiqaring

# %%
# Javobni shuyerga yozing
# Aholisi 1 milliondan ko‘p, maydoni 10,000 kv.km dan kichik hududlarni ajratib olish
df_filtered = df[(df["Aholisi"] > 1000000) & (df["Maydon"] < 10000)]

# Natijani chiqarish
print(df_filtered)
# Out:
#           Aholisi  Maydon
# Hudud
# Andijon   1899000    4200
# Farg'ona  2597000    6800
# Namangan  1862000    7900

# %%
#@title **To'g'ri javob**
# Aholisi 1 milliondan ko‘p, maydoni 10,000 kv.km dan kichik hududlarni ajratib olish
df_filtered = df[(df["Aholisi"] > 1000000) & (df["Maydon"] < 10000)]

# Natijani chiqarish
print(df_filtered)
# Out:
#           Aholisi  Maydon
# Hudud
# Andijon   1899000    4200
# Farg'ona  2597000    6800
# Namangan  1862000    7900

# %% [markdown]
# ### **15-mashq.**  Aholisi 1milliondan kam, lekin maydoni 10000kv.km dan ko'p hududlarni chiqaring

# %%
# Javobni shuyerga yozing
# Aholisi 1 milliondan kam, maydoni 10,000 kv.km dan katta hududlarni ajratib olish
df_filtered = df[(df["Aholisi"] < 1000000) & (df["Maydon"] > 10000)]

# Natijani chiqarish
print(df_filtered)
# Out:
#         Aholisi  Maydon
# Hudud
# Jizzax   910500   20500
# Navoiy   767500  110800

# %%
#@title **To'g'ri javob**
# Aholisi 1 milliondan kam, maydoni 10,000 kv.km dan katta hududlarni ajratib olish
df_filtered = df[(df["Aholisi"] < 1000000) & (df["Maydon"] > 10000)]

# Natijani chiqarish
print(df_filtered)
# Out:
#         Aholisi  Maydon
# Hudud
# Jizzax   910500   20500
# Navoiy   767500  110800

# %% [markdown]
# ### **16-mashq.**  Yuqoridagi df dan `Markaz` ustunini tashlab yuboring

# %%
# Javobni shuyerga yozing
# Avval barcha ustun nomlarini tekshiramiz
print(df.columns)

# Keyin agar "Markaz" ustuni bo‘lsa, uni olib tashlaymiz
if "Markaz" in df.columns:
    df = df.drop(columns=["Markaz"])
else:
    print("❌ Xatolik: 'Markaz' ustuni mavjud emas!")

# Yangilangan df ni chiqaramiz
print(df.head())
# Out:
# Index(['Aholisi', 'Maydon'], dtype='object')
# ❌ Xatolik: 'Markaz' ustuni mavjud emas!
#           Aholisi  Maydon
# Hudud
# Andijon   1899000    4200
# Buxoro    1384700   39400
# Farg'ona  2597000    6800
# Jizzax     910500   20500
# Namangan  1862000    7900

# %%
#@title **To'g'ri javob**
# Avval barcha ustun nomlarini tekshiramiz
print(df.columns)

# Keyin agar "Markaz" ustuni bo‘lsa, uni olib tashlaymiz
if "Markaz" in df.columns:
    df = df.drop(columns=["Markaz"])
else:
    print("❌ Xatolik: 'Markaz' ustuni mavjud emas!")

# Yangilangan df ni chiqaramiz
print(df.head())
# Out:
# Index(['Aholisi', 'Maydon'], dtype='object')
# ❌ Xatolik: 'Markaz' ustuni mavjud emas!
#           Aholisi  Maydon
# Hudud
# Andijon   1899000    4200
# Buxoro    1384700   39400
# Farg'ona  2597000    6800
# Jizzax     910500   20500
# Namangan  1862000    7900

# %% [markdown]
# ### **17-mashq.**  Yuqoridagi df dan Sirdaryo viloyati aholisini chiqaring

# %%
# Javobni shuyerga yozing
# Agar "Hudud" indeks sifatida ishlatilayotgan bo'lsa
sirdaryo_aholisi = df.loc["Sirdaryo", "Aholisi"]
print(sirdaryo_aholisi)
# Out:
# 648100

# %%
#@title **To'g'ri javob**
# Agar "Hudud" indeks sifatida ishlatilayotgan bo'lsa
sirdaryo_aholisi = df.loc["Sirdaryo", "Aholisi"]
print(sirdaryo_aholisi)
# Out:
# 648100

# %% [markdown]
# ### **18-mashq.**  Yuqoridagi df dan Buxoro viloyati maydonini chiqaring

# %%
# Javobni shuyerga yozing
# Buxoro viloyatining maydonini chiqarish
buxoro_maydoni = df.loc["Buxoro", "Maydon"]
print("Buxoro viloyatining maydoni:", buxoro_maydoni)
# Out:
# Buxoro viloyatining maydoni: 39400

# %%
#@title **To'g'ri javob**
# Buxoro viloyatining maydonini chiqarish
buxoro_maydoni = df.loc["Buxoro", "Maydon"]
print("Buxoro viloyatining maydoni:", buxoro_maydoni)
# Out:
# Buxoro viloyatining maydoni: 39400

# %% [markdown]
# ### **19-mashq.**  Yuqoridagi df dan Toshkent viloyati maydoni O'zbekiston Respublikasining necha fozini tashkil qilishini toping

# %%
# Javobni shuyerga yozing
# Toshkent viloyati maydonini olish
toshkent_maydoni = df.loc["Toshkent", "Maydon"] if "Toshkent" in df.index else df[df["Hudud"] == "Toshkent"]["Maydon"].values[0]

# Umumiy maydonni hisoblash
umumiy_maydon = df["Maydon"].sum()

# Foiz hisoblash
toshkent_foizi = (toshkent_maydoni / umumiy_maydon) * 100

# Natijani chiqarish
print(f"Toshkent viloyati O‘zbekiston maydonining {toshkent_foizi:.2f}% qismini tashkil etadi.")
# Out:
# Toshkent viloyati O‘zbekiston maydonining 3.51% qismini tashkil etadi.

# %%
# Toshkent viloyati maydonini olish
toshkent_maydoni = df.loc["Toshkent", "Maydon"] if "Toshkent" in df.index else df[df["Hudud"] == "Toshkent"]["Maydon"].values[0]

# Umumiy maydonni hisoblash
umumiy_maydon = df["Maydon"].sum()

# Foiz hisoblash
toshkent_foizi = (toshkent_maydoni / umumiy_maydon) * 100

# Natijani chiqarish
print(f"Toshkent viloyati O‘zbekiston maydonining {toshkent_foizi:.2f}% qismini tashkil etadi.")
# Out:
# Toshkent viloyati O‘zbekiston maydonining 3.51% qismini tashkil etadi.

# %% [markdown]
# ### **20-mashq.**  Yuqoridagi df dan Toshkent viloyati aholisi O'zbekiston Respublikasining necha fozini tashkil qilishini toping

# %%
# Javobni shuyerga yozing
# Toshkent viloyati aholisini olish
toshkent_aholisi = df.loc["Toshkent", "Aholisi"] if "Toshkent" in df.index else df[df["Hudud"] == "Toshkent"]["Aholisi"].values[0]

# Umumiy aholi sonini hisoblash
umumiy_aholi = df["Aholisi"].sum()

# Foiz hisoblash
toshkent_foizi = (toshkent_aholisi / umumiy_aholi) * 100

# Natijani chiqarish
print(f"Toshkent viloyati O‘zbekiston aholisining {toshkent_foizi:.2f}% qismini tashkil etadi.")
# Out:
# Toshkent viloyati O‘zbekiston aholisining 20.46% qismini tashkil etadi.

# %%
# Toshkent viloyati aholisini olish
toshkent_aholisi = df.loc["Toshkent", "Aholisi"] if "Toshkent" in df.index else df[df["Hudud"] == "Toshkent"]["Aholisi"].values[0]

# Umumiy aholi sonini hisoblash
umumiy_aholi = df["Aholisi"].sum()

# Foiz hisoblash
toshkent_foizi = (toshkent_aholisi / umumiy_aholi) * 100

# Natijani chiqarish
print(f"Toshkent viloyati O‘zbekiston aholisining {toshkent_foizi:.2f}% qismini tashkil etadi.")
# Out:
# Toshkent viloyati O‘zbekiston aholisining 20.46% qismini tashkil etadi.
