# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjar-prog/Telegram-JavaScript-Bot/blob/main/Amaliyot_Kredit_berish_holatlarini_bashorat_qilish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Kerakli kutubxonalarni yuklab olamiz

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Processing

# %%
# Dataset'ni pandas Dataframe'ga yuklaymiz
loan_dataset = pd.read_csv('/housing_LR.csv')

# %%
type(loan_dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
# Dataframe'ning dastlabki 5 qatorini chop etamiz
loan_dataset.head()
# Out:
#    Unnamed: 0       district  rooms  size  level  max_levels    price
# 0           0   Юнусабадский      3  57.0      4           4  52000.0
# 1           1  Яккасарайский      2  52.0      4           5  56000.0
# 2           2   Чиланзарский      2  42.0      4           4  37000.0
# 3           3   Чиланзарский      3  65.0      1           4  49500.0
# 4           4   Чиланзарский      3  70.0      3           5  55000.0

# %%
# Qatorlar va ustunlar soni
loan_dataset.shape
# Out:
# (7278, 7)

# %%
# Statistical measures
loan_dataset.describe()
# Out:
#         Unnamed: 0        rooms        size        level   max_levels  \
# count  7278.000000  7278.000000  7278.00000  7278.000000  7278.000000
# mean   3735.910552     2.578318    70.11898     3.689338     5.992718
# std    2162.154719     1.030179    29.32120     2.228360     2.583194
# min       0.000000     1.000000     1.00000     1.000000     1.000000
# 25%    1862.250000     2.000000    50.00000     2.000000     4.000000
# 50%    3737.500000     2.000000    65.00000     3.000000     5.000000
# 75%    5611.750000     3.000000    83.00000     5.000000     9.000000
# max    7464.000000     8.000000   279.00000    18.000000    25.000000
#
#                price
# count    7278.000000
# mean    54092.074196
# std     29665.210900
# min         2.000000
# 25%     34800.000000
# 50%     45500.000000
# 75%     65000.000000
# max    220000.000000

# %%
# Har bir ustunda yetishmayotgan qiymatlar
loan_dataset.isnull().sum()
# Out:
# Unnamed: 0    0
# district      0
# rooms         0
# size          0
# level         0
# max_levels    0
# price         0
# dtype: int64

# %%
# Yetishmayotgan qiymatlarni o'chirish
loan_dataset = loan_dataset.dropna()

# %%
loan_dataset.isnull().sum()
# Out:
# Unnamed: 0    0
# district      0
# rooms         0
# size          0
# level         0
# max_levels    0
# price         0
# dtype: int64

# %%
# Label encoding
loan_dataset.replace({"Loan_Status":{'N':0, 'Y':1}}, inplace=True)

# %%
# DataFrame'ning birinchi 5 qatorini chop etamiz
loan_dataset.head()
# Out:
#    Unnamed: 0       district  rooms  size  level  max_levels    price
# 0           0   Юнусабадский      3  57.0      4           4  52000.0
# 1           1  Яккасарайский      2  52.0      4           5  56000.0
# 2           2   Чиланзарский      2  42.0      4           4  37000.0
# 3           3   Чиланзарский      3  65.0      1           4  49500.0
# 4           4   Чиланзарский      3  70.0      3           5  55000.0

# %%
# Dependent ustun qiymatlari
loan_dataset['Dependents'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Dependents'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-4f905e6f6034> in <cell line: 0>()
#       1 # Dependent ustun qiymatlari
# ...

# %%
# 3+ qiymatlarini 4 ga o'zgartiramiz
loan_dataset = loan_dataset.replace(to_replace='3+', value=4)

# %%
# Dependent qiymatlari
loan_dataset['Dependents'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Dependents'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-5c6f686a3a6d> in <cell line: 0>()
#       1 # Dependent qiymatlari
# ...

# %% [markdown]
# Data Visualization

# %%
# Education & Loan Status
sns.countplot(x="Education", hue="Loan_Status", data=loan_dataset)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-bdc456f3f97e> in <cell line: 0>()
#       1 # Education & Loan Status
# ----> 2 sns.countplot(x="Education", hue="Loan_Status", data=loan_dataset)
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2629         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2630
# -> 2631     p = _CategoricalAggPlotter(
#    2632         data=data,
#    2633         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      65     ):
#      66
# ...

# %%
# Marital Status & Loan Status
sns.countplot(x='Married', hue='Loan_Status',data=loan_dataset)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-4df50ec36905> in <cell line: 0>()
#       1 # Marital Status & Loan Status
# ----> 2 sns.countplot(x='Married', hue='Loan_Status',data=loan_dataset)
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2629         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2630
# -> 2631     p = _CategoricalAggPlotter(
#    2632         data=data,
#    2633         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      65     ):
#      66
# ...

# %%
# Kategorik usutnlarni, raqamliga (numerical) o'zgartirish
loan_dataset.replace({'Married':{'No':0, 'Yes':1}, 'Gender':{'Male':1, 'Female':0}, 'Self_Empoyed':{'No':0, 'Yes':1}, 'Property_Area':{"Rural":0, 'Semiurban':1, 'Urban':2}, 'Education':{'Gradute':1, 'Not Gradute':0}}, inplace=True)

# %%
loan_dataset.head()
# Out:
#    Unnamed: 0       district  rooms  size  level  max_levels    price
# 0           0   Юнусабадский      3  57.0      4           4  52000.0
# 1           1  Яккасарайский      2  52.0      4           5  56000.0
# 2           2   Чиланзарский      2  42.0      4           4  37000.0
# 3           3   Чиланзарский      3  65.0      1           4  49500.0
# 4           4   Чиланзарский      3  70.0      3           5  55000.0

# %%
# Ma'lumotlarni ajratish va labellash
X = loan_dataset.drop(columns=['Loan_ID', 'Loan_Status'], axis=1)
Y = loan_dataset['Loan_Status']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-a2c766f4377c> in <cell line: 0>()
#       1 # Ma'lumotlarni ajratish va labellash
# ----> 2 X = loan_dataset.drop(columns=['Loan_ID', 'Loan_Status'], axis=1)
#       3 Y = loan_dataset['Loan_Status']
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# ...

# %%
print(X)
print(Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-7f37a9e12cb7> in <cell line: 0>()
# ----> 1 print(X)
#       2 print(Y)
#
# NameError: name 'X' is not defined

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, stratify=Y, random_state=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-40909de7c1f7> in <cell line: 0>()
# ----> 1 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, stratify=Y, random_state=2)
#
# NameError: name 'X' is not defined

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-ced9ad7b4c10> in <cell line: 0>()
# ----> 1 print(X.shape, X_train.shape, X_test.shape)
#
# NameError: name 'X' is not defined

# %% [markdown]
# Training the Model:
# Support Vector Machine Model

# %%
classifier = svm.SVC(kernel='linear')

# %%
# Support Vector Machine Model'ini Train qilish
classifier.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-008b6e46bbaa> in <cell line: 0>()
#       1 # Support Vector Machine Model'ini Train qilish
# ----> 2 classifier.fit(X_train, Y_train)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# Model Evalution

# %%
# Training Data'ning accuracy score'i
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-ff2a62911300> in <cell line: 0>()
#       1 # Training Data'ning accuracy score'i
# ----> 2 X_train_prediction = model.predict(X_train)
#       3 training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
#       4 print('Accuracy score of the training data : ', training_data_accuracy)
#
# NameError: name 'model' is not defined

# %%
print("Accuracy data score : ", Training_data_accuray)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-586f8c9e0779> in <cell line: 0>()
# ----> 1 print("Accuracy data score : ", Training_data_accuray)
#
# NameError: name 'Training_data_accuray' is not defined

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-33c1146d295c> in <cell line: 0>()
# ----> 1 X_test_prediction = model.predict(X_test)
#       2 test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
#
# NameError: name 'model' is not defined

# %%
print("Accuracy data score : ", Test_data_accuray)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-ea525871ce08> in <cell line: 0>()
# ----> 1 print("Accuracy data score : ", Test_data_accuray)
#
# NameError: name 'Test_data_accuray' is not defined

# %%
# test Data'ning accuracy score'i
